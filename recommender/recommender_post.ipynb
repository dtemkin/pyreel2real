# %% [markdown]
# ## Overview
#
# ### Summary
#
#
#
#
# ### Data Collection
#
#
#
# ##### Data Source Map

# %% [markdown]
# ## Preprocessing
#
#
# #### Categorical Variable Encoding
#
#
#
#      selected      variables                sample                            type
#
#          *          genres          ["horror","drama","fantasy"]           string array
#          *          actors         ["George Clooney","Brad Pitt"]          string array
#          *         imdbRating                7.6                              float
#          *         imdbVotes                10234                            integer
#                     writers             ["J.K. Rowling"]                   string array
#                    directors            ["Danny Boyle"]                    string array
#
#
# #### Model Selection

# %% [markdown]
# ## Model Results
#
#
# ### Decision Tree Classifier:
#
#
#
# #### Labeled Data Metrics
#
# ##### Classification Report
#                precision   recall   f1-score   support    avg. prob.
#
#           0       0.84      0.78      0.81      1053       0.4204
#           1       0.83      0.88      0.85      1283       0.5796
#         ----      ----      ----      ----      ----
#       avg/total   0.83      0.83      0.83      2336
#
# ##### Cross-Validation:
#
#     [ 0.93181818  0.91477273
#       0.93714286  0.91428571
#       0.89142857  0.91428571
#       0.93714286  0.89714286
#       0.90285714  0.90857143 ]
#
# ##### ROC - AUC:
#
#     0.8297
#
#
#
# #### Unlabeled Data Metrics
#
# ##### Classification Report
#                 precision  recall   f1-score    support    avg. prob.
#
#           0       0.67      0.40      0.50        77        0.3129
#           1       0.54      0.79      0.64        70        0.6871
#         ----      ----      ----      ----      -----
#       avg/total   0.61      0.59      0.57       147
#
# ##### Cross-Validation:
#
#     [ 0.96022727  0.89204545
#       0.91428571  0.88
#       0.93714286  0.93142857
#       0.96571429  0.93142857
#       0.96        0.94285714 ]
#
# ##### ROC - AUC:
#
#     0.5942
#
#
#
# ### Random Forest Classifier:
#
#
#
# #### Labeled Data Metrics
#
# ##### Classification Report
#                precision    recall    f1-score   support    avg. prob.
#
#           0       0.94       0.96       0.95      1053       0.4544
#           1       0.97       0.95       0.96      1283       0.5456
#         ----      ----       ----       ----      ----
#       avg/total   0.96       0.96       0.96      2336
#
# ##### Cross-Validation:
#
#     [ 0.98863636  0.96590909
#       0.98863636  0.96022727
#       0.98295455  0.98863636
#       0.99425287  1.000
#       0.98850575  0.99425287 ]
#
# ##### ROC - AUC:
#
#     0.9554
#
#
#
# #### Unlabeled Data Metrics
#
# ##### Classification Report
#                precision   recall   f1-score   support   avg. prob.
#
#           0       0.50      0.06      0.11       77       0.1401
#           1       0.47      0.93      0.63       70       0.8599
#         ----      ----      ----      ----      -----
#       avg/total   0.49      0.48      0.36       147
#
# ##### 10 Fold - Cross-Validation:
#
#     [ 0.98295455  0.96590909
#       0.98295455  0.95454545
#       0.98863636  0.98863636
#       1.00        0.99425287
#       0.98275862  0.99425287 ]
#
# ##### ROC - AUC:
#
#     0.4909
#
#
#
#
# ### Logistic Regression:
#
#
#
# #### Labeled Data Metrics
#
# ##### Classification Report
#                precision   recall   f1-score   support   avg. prob.
#
#           0       0.00      0.00      0.00      1053       0.4559
#           1       0.55      1.00      0.71      1283       0.5441
#         ----      ----      ----      ----      ----
#       avg/total   0.30      0.55      0.39      2336
#
# ##### Cross-Validation:
#
#     [ 0.54545455  0.54545455
#       0.54545455  0.54285714
#       0.54285714  0.54285714
#       0.54285714  0.54285714
#       0.54285714  0.54597701 ]
#
# ##### ROC - AUC:
#
#     0.5
#
#
#
# #### Unlabeled Data Metrics
#
# ##### Classification Report
#                precision    recall    f1-score   support    avg. prob.
#
#           0       0.00       0.00       0.00       77        0.4239
#           1       0.48       1.00       0.65       70        0.5760
#         ----      ----       ----       ----      -----
#       avg/total   0.23       0.48       0.31       147
#
#
#
# ##### Cross-Validation:
#
#     [ 0.54545455  0.54545455
#       0.54545455  0.54285714
#       0.54285714  0.54285714
#       0.54285714  0.54285714
#       0.54285714  0.54597701 ]
#
# ##### ROC - AUC:
#
#     0.5

# %% [markdown]
# ## Conclusion
